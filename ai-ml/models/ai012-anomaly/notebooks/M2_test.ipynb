# %%
import sys
from pathlib import Path

# makes "src" visible
sys.path.append(str(Path.cwd().parent))

# %%
import numpy as np
import pandas as pd

# synthetic or placeholder dataset (replace later with real processed data)
df = pd.DataFrame(np.random.rand(200, 8), columns=[f"f{i}" for i in range(8)])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\munig\Desktop\Phoenix\.venv\Lib\site-packages\numpy\_core\__init__.py:24
#      23 try:
# ---> 24     from . import multiarray
#      25 except ImportError as exc:
#
# File c:\Users\munig\Desktop\Phoenix\.venv\Lib\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *  # noqa: F403
#
# ImportError: DLL load failed while importing _multiarray_umath: The specified procedure could not be found.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#       3
#       4 # synthetic or placeholder dataset (replace later with real processed data)
#
# File c:\Users\munig\Desktop\Phoenix\.venv\Lib\site-packages\numpy\__init__.py:125
#     122 from . import _distributor_init
#     124 try:
# --> 125     from numpy.__config__ import show_config
#     126 except ImportError as e:
#     127     if isinstance(e, ModuleNotFoundError) and e.name == "numpy.__config__":
#     128         # The __config__ module itself was not found, so add this info:
#
# File c:\Users\munig\Desktop\Phoenix\.venv\Lib\site-packages\numpy\__config__.py:4
#       1 # This file is generated by numpy's build process
#       2 # It contains system_info results at the time of building this package.
#       3 from enum import Enum
# ----> 4 from numpy._core._multiarray_umath import (
#       5     __cpu_features__,
#       6     __cpu_baseline__,
#       7     __cpu_dispatch__,
#       8 )
#      10 __all__ = ["show_config"]
#      11 _built_with_meson = True
#
# File c:\Users\munig\Desktop\Phoenix\.venv\Lib\site-packages\numpy\_core\__init__.py:85
#      58     major, minor, *_ = sys.version_info
#      59     msg = f"""
#      60
#      61 IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#    (...)     82 Original error was: {exc}
#      83 """
# ---> 85     raise ImportError(msg) from exc
#      86 finally:
#      87     for envkey in env_added:
#
# ImportError:
#
# IMPORTANT: PLEASE READ THIS FOR ADVICE ON HOW TO SOLVE THIS ISSUE!
#
# Importing the numpy C-extensions failed. This error can happen for
# many reasons, often due to issues with your setup or how NumPy was
# installed.
#
# We have compiled some common reasons and troubleshooting tips at:
#
#     https://numpy.org/devdocs/user/troubleshooting-importerror.html
#
# Please note and check the following:
#
#   * The Python version is: Python 3.14 from "c:\Users\munig\Desktop\Phoenix\.venv\Scripts\python.exe"
#   * The NumPy version is: "2.4.4"
#
# and make sure that they are the versions you expect.
#
# Please carefully study the information and documentation linked above.
# This is unlikely to be a NumPy issue but will be caused by a bad install
# or environment on your machine.
#
# Original error was: DLL load failed while importing _multiarray_umath: The specified procedure could not be found.

# %%
from src.models.M2 import AI012M2_LOF

print("=== M2 LOF TESTING ===")

model = AI012M2_LOF()
model.fit(df)  # in unsupervised models, fit is required before test

output = model.build_output(df)

print(output.head())

print("\nAnomaly Summary:")
print("Total anomalies:", output["anomaly_flag"].sum())
print("Score min/max:", output["anomaly_score"].min(), output["anomaly_score"].max())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.models.M2 import AI012M2_LOF
#       2
#       3 print("=== M2 LOF TESTING ===")
#       4
#
# ModuleNotFoundError: No module named 'src'

# %%
print("\nValue counts:")
print(output["anomaly_flag"].value_counts())
# Out:
# Value counts:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 print("\nValue counts:")
# ----> 2 print(output["anomaly_flag"].value_counts())
#
# NameError: name 'output' is not defined
