# %%
import sys
from pathlib import Path

# Add project root to Python path
project_root = Path().resolve().parents[1]  # ai012-anomaly root
sys.path.append(str(project_root))

# %%
import sys
from pathlib import Path

# makes "src" visible
sys.path.append(str(Path.cwd().parent))

# %%
import numpy as np
import pandas as pd

# synthetic or placeholder dataset (replace later with real processed data)
df = pd.DataFrame(np.random.rand(200, 8), columns=[f"f{i}" for i in range(8)])

# %%
from src.models.M2 import AI012M2_LOF

print("=== M2 LOF TRAINING ===")

model = AI012M2_LOF()

# fit model
model.fit(df)

print("Model fitted successfully")
print("Feature columns:", model.feature_columns)
# Out:
# === M2 LOF TRAINING ===
# Model fitted successfully
# Feature columns: ['f0', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7']

# %%
import joblib

joblib.dump(model, "../checkpoints/M2_LOF.pkl")

print("M2 checkpoint saved successfully.")
