# %%
#CELL 1

import sys
import os
import pandas as pd

sys.path.append("../src")

from models.one_class_svm import OneClassSVMModel

# %%
#CELL 2

BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))

DATASET_PATH = os.path.join(
    BASE_DIR,
    "data",
    "processed",
    "features_output.csv"
)

OUTPUT_DIR = os.path.join(BASE_DIR, "data", "outputs")
MODEL_PATH = os.path.join(BASE_DIR, "checkpoints", "ocsvm.pkl")

print("Dataset:", DATASET_PATH)

# %%
#CELL 3

df = pd.read_csv(DATASET_PATH)
df.head()

# %%
#CELL 4

model = OneClassSVMModel()
result_df = model.run(DATASET_PATH, OUTPUT_DIR, MODEL_PATH)

# %%
#CELL 5

result_df[["anomaly_score", "anomaly_flag", "anomaly_rank"]].head(10)

# %%
#CELL 6

result_df["anomaly_flag"].value_counts()

# %%
#CELL 7

"""
One-Class SVM learns a boundary around normal behaviour.

Strengths:
- good for novelty detection
- detects unseen attack patterns

Weakness:
- slow on large datasets
- sensitive to scaling
"""
