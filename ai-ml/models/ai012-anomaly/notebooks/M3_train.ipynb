# %%
import sys
from pathlib import Path

# makes "src" visible
sys.path.append(str(Path.cwd().parent))

# %%
import numpy as np
import pandas as pd

# synthetic or placeholder dataset (replace later with real processed data)
df = pd.DataFrame(np.random.rand(200, 8), columns=[f"f{i}" for i in range(8)])

# %%
from src.models.M3 import AI012M3_OneClassSVM

print("=== M3 ONE-CLASS SVM TRAINING ===")

model = AI012M3_OneClassSVM()

model.fit(df)

print("Model fitted successfully")
# Out:
# === M3 ONE-CLASS SVM TRAINING ===
# Model fitted successfully

# %%
import joblib

joblib.dump(model, "../checkpoints/M3_OneClassSVM.pkl")

print("M3 checkpoint saved successfully.")
