# %%
import json


report_path = "../../../../training_pipeline/reports/aarnav_gb_core_v1_experiment_summary.json"

with open(report_path, 'r') as file:
    report = json.load(file)

print("=== CORE V1: GRADIENT BOOSTING EVALUATION ===")
print(f"Test Accuracy:  {report['metrics']['test']['accuracy']:.4f}")
print(f"Test F1 Score:  {report['metrics']['test']['f1']:.4f}")
print(f"Test AUC:       {report['metrics']['test']['auc']:.4f}")
print(f"Test Precision: {report['metrics']['test']['precision']:.4f}")
print(f"Test Recall:    {report['metrics']['test']['recall']:.4f}")

# %% [markdown]
# ### 1. Validation Data Metrics
# These plots represent the model's performance on the validation split.
#
# ![Validation Metrics](../images/val_metrics_bar.png)
# ![Validation Confusion Matrix](../images/val_confusion_matrix.png)
#
# ---
#
# ### 2. Test Data Metrics
# These plots represent the model's final performance on the unseen test split.
#
# ![Test Metrics](../images/test_metrics_bar.png)
# ![Test Confusion Matrix](../images/test_confusion_matrix.png)
#
# ---
#
# ### 3. TensorBoard Logs
# Static outputs of the final evaluation scalars logged to TensorBoard.
#
# ![TensorBoard Scalars](../images/tensorboard_scalars.png)
