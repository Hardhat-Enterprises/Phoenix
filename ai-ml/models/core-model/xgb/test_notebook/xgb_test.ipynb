# %%
# %load_ext autoreload
# %autoreload 2



import sys
import os

from pathlib import Path
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report
import pandas as pd
from xgboost import XGBClassifier


sys.path.append('../../../../training_pipeline')
from src.core.pipeline import TrainingPipeline

ROOT = Path("../../../../").resolve()

sys.path.append('../../../../cleaning')


df = pd.read_csv(
    ROOT / "datasets" / "phoenix_combined_dataset_large.csv"
)


sys.path.append('../../../../training_pipeline')



config_path = "configs/xgboost_config.yaml"

print("Initializing Training Pipeline for Gradient Boosting...")

pipeline = TrainingPipeline(config_path=config_path)

pipeline.set_model_instance(
    XGBClassifier(),  # fresh instance
    model_name="xgboost",
    task_type="classification"
)


# To run the training natively in this notebook, uncomment the lines below:
print("Starting training...")


result = pipeline.run(run_id="trey_xgb_core_v1")
print(f"Training Complete! Reports saved to: {result['reports']}")

print("Pipeline configured successfully. Run via CLI or uncomment the code above to execute.")
# Out:
# 2026-05-10 20:20:48,452 | INFO | training_pipeline | CONFIG SNAPSHOT
# 2026-05-10 20:20:48,455 | INFO | training_pipeline | CONFIG | section=dataset | value={"path": "../datasets/phoenix_combined_dataset_large.csv", "target_column": "hazard_severity", "train_split": 0.7, "val_split": 0.15, "test_split": 0.15, "random_seed": 42, "stratify": true, "abnormal_path": ""}
# 2026-05-10 20:20:48,458 | INFO | training_pipeline | CONFIG | section=cleaning | value={"remove_duplicates": {"enabled": true}, "missing_values": {"enabled": true, "strategy": "fill"}, "text_cleaning": {"enabled": true, "lowercase": true, "remove_urls": true, "remove_punctuation": true, "remove_extra_whitespace": true}}
# 2026-05-10 20:20:48,462 | INFO | training_pipeline | CONFIG | section=preprocessing | value={"datetime_features": {"enabled": true, "columns": ["timestamp", "hazard_timestamp"], "drop_original": true}, "url_features": {"enabled": true, "columns": ["url"], "drop_original": true}, "text_vectorization": {"enabled": true, "column": "text", "max_features": 3000, "ngram_range": [1, 2]}, "label_encoding": {"enabled": false}, "encoding": "onehot", "normalization": "standard", "feature_selection": false, "missing_value_strategy": "mean", "selected_features": []}
# 2026-05-10 20:20:48,463 | INFO | training_pipeline | CONFIG | section=model | value={"type": "sklearn", "name": "xgboost", "hyperparameters": {"n_estimators": 100, "learning_rate": 0.1, "max_depth": 3, "random_state": 42, "use_label_encoder": false, "eval_metric": "mlogloss"}, "task_type": ""}
# 2026-05-10 20:20:48,465 | INFO | training_pipeline | CONFIG | section=training | value={"evaluate_on_test": true, "tensorboard_enabled": true, "verbose": true, "batch_size": 32, "epochs": 50, "learning_rate": 0.001, "tensorboard_log_dir": "logs/tensorboard"}
# 2026-05-10 20:20:48,466 | INFO | training_pipeline | CONFIG | section=output | value={"run_id": "trey_gb_core_v1", "log_dir": "logs/", "checkpoint_dir": "checkpoints/", "report_dir": "reports/", "path": "checkpoints/", "save_best_only": true, "organize_checkpoints_by_run": true, "previous_checkpoints_to_keep": 3, "checkpoint_prefix": "model", "log_path": "logs/", "reports_path": "reports/"}
# 2026-05-10 20:20:48,483 | INFO | training_pipeline | Dataset loaded | main_rows=2000 | abnormal_rows=0 | combined_rows=2000
# 2026-05-10 20:20:48,529 | INFO | training_pipeline | Preprocessing complete | processed_rows=2000 | processed_columns=3572 | preprocessing_events=11
# 2026-05-10 20:20:48,553 | INFO | training_pipeline | Label encoding applied | classes=["critical", "high", "low", "medium"]
# 2026-05-10 20:20:48,584 | INFO | training_pipeline | Training started | model_name=xgboost | model_type=sklearn | epochs=50 | batch_size=32 | train_rows=1400
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Initializing Training Pipeline for Gradient Boosting...
# Starting training...
# 2026-05-10 20:20:52,010 | INFO | training_pipeline | Training complete | model_name=xgboost | model_type=sklearn | task_type=classification
# [train] model=xgboost type=sklearn status=trained
# 2026-05-10 20:20:54,259 | INFO | training_pipeline | METRIC | metric=val_accuracy | value=0.7566666666666667
# 2026-05-10 20:20:54,259 | INFO | training_pipeline | METRIC | metric=val_precision | value=0.755655737704918
# 2026-05-10 20:20:54,260 | INFO | training_pipeline | METRIC | metric=val_recall | value=0.7566666666666667
# 2026-05-10 20:20:54,261 | INFO | training_pipeline | METRIC | metric=val_f1 | value=0.7528471768040114
# 2026-05-10 20:20:54,261 | INFO | training_pipeline | METRIC | metric=val_confusion_matrix | value=[[91, 0, 0, 0], [0, 57, 0, 28], [0, 0, 46, 0], [0, 45, 0, 33]]
# 2026-05-10 20:20:54,263 | INFO | training_pipeline | METRIC | metric=val_auc | value=0.9127617501222153
# 2026-05-10 20:20:54,264 | INFO | training_pipeline | METRIC | metric=test_accuracy | value=0.7233333333333334
# 2026-05-10 20:20:54,264 | INFO | training_pipeline | METRIC | metric=test_precision | value=0.7220619195046439
# 2026-05-10 20:20:54,265 | INFO | training_pipeline | METRIC | metric=test_recall | value=0.7233333333333334
# 2026-05-10 20:20:54,266 | INFO | training_pipeline | METRIC | metric=test_f1 | value=0.7214827905091273
# 2026-05-10 20:20:54,266 | INFO | training_pipeline | METRIC | metric=test_confusion_matrix | value=[[90, 0, 0, 0], [0, 48, 0, 36], [0, 0, 47, 0], [0, 47, 0, 32]]
# 2026-05-10 20:20:54,267 | INFO | training_pipeline | METRIC | metric=test_auc | value=0.9005817761577566
# 2026-05-10 20:20:54,287 | INFO | training_pipeline | Checkpoint saved | checkpoint_path=checkpoints/trey_xgb_core_v1/model_xgboost_trey_xgb_core_v1_final.joblib
# [eval] validation: accuracy=0.7567 | precision=0.7557 | recall=0.7567 | f1=0.7528 | auc=0.9128
# [eval] test: accuracy=0.7233 | precision=0.7221 | recall=0.7233 | f1=0.7215 | auc=0.9006
# Training Complete! Reports saved to: {'experiment_summary_json': 'reports/trey_xgb_core_v1_experiment_summary.json', 'experiment_summary_md': 'reports/trey_xgb_core_v1_experiment_summary.md'}
# Pipeline configured successfully. Run via CLI or uncomment the code above to execute.
